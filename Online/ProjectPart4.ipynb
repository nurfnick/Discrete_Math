# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Discrete_Math/blob/master/Online/ProjectPart4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Counting
#
# ### Dr. Jacob's Incorrect Submission

# %% [markdown]
# I'll continue down my path looking at craps
#
# ![image.png](data:image/png;base64,...)

# %%
possibleComeOutRolls = ['natural','craps','point']

# %% [markdown]
# ## 1 Counting

# %% [markdown]
# There are three options in my sequence of ten so there are $3^{10}$ options!
#
# For each of the ten rolls I am doing there will be three possibilities!
#
# $$ 3*3*3\dots *3 = 3^{10} $$

# %%
3**10
# Out:
# 59049

# %% [markdown]
# If order didn't matter than you'd have to use the more complicated formula since there is replacement!  If there are $n$ objects and $k$ slots but order does not matter, the number of ways to do this is
#
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$
#
# You should flip your thinking here as there will be 10 objects it is just that there are only 3 categories that they can fall into.

# %%
import math

math.factorial(12)/(math.factorial(10)*math.factorial(2))
# Out:
# 66.0

# %% [markdown]
# That is a huge difference!
#
# With only 66 maybe we can have the computer print them all for us!

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(possibleComeOutRolls,10)))
# Out:
# [('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'point'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps', 'craps'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps', 'point'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'point', 'point'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps', 'craps', 'craps'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps', 'craps', 'point'), ('natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'craps', 'point', 'point'), ('natural', 'natural', 
# ...

# %% [markdown]
# Not terribly readable, it does have the right number of elements...

# %%
len(list(combinations_with_replacement(possibleComeOutRolls,10)))
# Out:
# 66

# %% [markdown]
# ## Now without replacement!

# %% [markdown]
# I cannot do ten without replacement, actually I can only do three at the most...
#
# If order matters it is $3!$ and if not $\binom33$.

# %%
print(math.factorial(3))
# Out:
# 6

# %% [markdown]
# Let's show all 6

# %%
from itertools import permutations
print(list(permutations(possibleComeOutRolls,3)))
# Out:
# [('natural', 'craps', 'point'), ('natural', 'point', 'craps'), ('craps', 'natural', 'point'), ('craps', 'point', 'natural'), ('point', 'natural', 'craps'), ('point', 'craps', 'natural')]

# %% [markdown]
# If order doesn't matter?

# %%
math.factorial(3)/(math.factorial(0)*math.factorial(3))
# Out:
# 1.0

# %% [markdown]
# And the only answer is

# %%
from itertools import combinations
print(list(combinations(possibleComeOutRolls,3)))
# Out:
# [('natural', 'craps', 'point')]

# %% [markdown]
# I'll leave the last question for y'all
