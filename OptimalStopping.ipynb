# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Discrete_Math/blob/master/OptimalStopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations

# %%
perm = list(permutations([1,2,3,4,5,6]))

# %% [markdown]
# There are $6!$ different possible permutations of these.  This is
# $$
# 6! = 6\times 5\times 4\times 3 \times 3\times 2\times 1 = 720
# $$

# %%
for i in perm:
  print(i)
# Out:
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 6, 5)
# (1, 2, 3, 5, 4, 6)
# (1, 2, 3, 5, 6, 4)
# (1, 2, 3, 6, 4, 5)
# (1, 2, 3, 6, 5, 4)
# (1, 2, 4, 3, 5, 6)
# (1, 2, 4, 3, 6, 5)
# (1, 2, 4, 5, 3, 6)
# (1, 2, 4, 5, 6, 3)
# (1, 2, 4, 6, 3, 5)
# (1, 2, 4, 6, 5, 3)
# (1, 2, 5, 3, 4, 6)
# (1, 2, 5, 3, 6, 4)
# (1, 2, 5, 4, 3, 6)
# (1, 2, 5, 4, 6, 3)
# (1, 2, 5, 6, 3, 4)
# (1, 2, 5, 6, 4, 3)
# (1, 2, 6, 3, 4, 5)
# (1, 2, 6, 3, 5, 4)
# (1, 2, 6, 4, 3, 5)
# (1, 2, 6, 4, 5, 3)
# (1, 2, 6, 5, 3, 4)
# (1, 2, 6, 5, 4, 3)
# (1, 3, 2, 4, 5, 6)
# (1, 3, 2, 4, 6, 5)
# (1, 3, 2, 5, 4, 6)
# (1, 3, 2, 5, 6, 4)
# (1, 3, 2, 6, 4, 5)
# (1, 3, 2, 6, 5, 4)
# (1, 3, 4, 2, 5, 6)
# (1, 3, 4, 2, 6, 5)
# (1, 3, 4, 5, 2, 6)
# (1, 3, 4, 5, 6, 2)
# (1, 3, 4, 6, 2, 5)
# (1, 3, 4, 6, 5, 2)
# (1, 3, 5, 2, 4, 6)
# (1, 3, 5, 2, 6, 4)
# (1, 3, 5, 4, 2, 6)
# (1, 3, 5, 4, 6, 2)
# (1, 3, 5, 6, 2, 4)
# (1, 3, 5, 6, 4, 2)
# (1, 3, 6, 2, 4, 5)
# (1, 3, 6, 2, 5, 4)
# (1, 3, 6, 4, 2, 5)
# (1, 3, 6, 4, 5, 2)
# (1, 3, 6, 5, 2, 4)
# ...

# %%
6*0.37
# Out:
# 2.2199999999999998

# %% [markdown]
# So the theory suggests that we interview two people and then take the one we see that is better than all the rest.

# %%
import random 
example = perm[random.randrange(720)]
print(example)
# Out:
# (5, 6, 4, 1, 2, 3)

# %%
def nextbest(permutation, lookbest, startlookingat):
  for indiv in permutation[startlookingat:]:
    if indiv > lookbest:
      return indiv
  return 0 



nextbest(example, 5,2)
# Out:
# 0

# %%
numberOfBests = 0
for i in perm:
  maximum = max(i[0:2])
  if nextbest(i,maximum,2) == 6:
    numberOfBests = numberOfBests + 1

# %%
numberOfBests/720
# Out:
# 0.42777777777777776
