# %% [markdown]
#                                                          Module 5 Project
#                                                          Biraj Thapa
#                                                          CPSMA-3913-01
#                                                          Instructor(s): Nicholas C Jacob, PhD
#
#
# # Description of Scenario
#
#   This is a descion tree based on the time when I am hungry. Descions are made based on the availability of certain items or products. A descion tree would be the most appropriate representation of my scenario. The Graph has 7 vertex and 6 edges. The descions are labeled by 'Yes' or 'No' in my Graph.

# %%
from graphviz import Digraph
dot = Digraph()

# %% [markdown]
# # Structure of Descion Tree

# %%
import graphviz

g = graphviz.Digraph('G')

g.edge('Am I Hungry?', 'Check Refrigerator for food',label = 'Yes')
g.edge('Am I Hungry?', 'Go to Sleep',label = 'No')
g.edge('Check Refrigerator for food','Cook',label = 'Yes')
g.edge('Check Refrigerator for food','Check if money available?', label ='No')
g.edge('Check if money available?','Order Food', label = 'Yes')
g.edge('Check if money available?','Dont Order', label ='No')

# %% [markdown]
# # Visualization of Tree

# %%
g

# %% [markdown]
# # Check whether it's Tree or Graph

# %%
def check(degree, n): 
      
    # Find sum of all degrees 
    deg_sum = sum(degree) 
      
    # It is tree if sum is equal to 2(n-1) 
    if (2*(n-1) == deg_sum): 
        return True
    else: 
        return False
      
#main 
n = 7
degree = [2, 3, 1, 1, 3, 1, 1]; 
if (check(degree, n)): 
    print("Tree")
else: 
    print ("Graph")
# Out:
# Tree

# %% [markdown]
# # Path of this structure

# %%
import graphviz

g = graphviz.Digraph('G')

g.edge('Am I Hungry? Node 1', 'Check Refrigerator for food',label = 'Yes')
g.edge('Am I Hungry? Node 1', 'Go to Sleep',label = 'No')
g.edge('Check Refrigerator for food','Cook',label = 'Yes')
g.edge('Check Refrigerator for food','Check if money available?', label ='No')
g.edge('Check if money available?','Order Food Node 2', label = 'Yes')
g.edge('Check if money available?','Dont Order', label ='No')
g

# %% [markdown]
# To describe a specific path, I've specified the root node as Node 1 and the leaf node i.e., Order Food as Node 2.
#
# Path between "Am I hungry?" and "Order Food": [Am I hungry?-Check Refrigerator for food-Check if money available?-Order Food]
# Depth of Order Food : 3
# In any tree, the depth of the tree is longest path from root to it's node, so the depth of tree is also 3.

# %% [markdown]
# # Degree Of A Vertex

# %%
import graphviz

g = graphviz.Digraph('G')

g.edge('Am I Hungry?', 'Check Refrigerator for food',label = 'Yes')
g.edge('Am I Hungry?', 'Go to Sleep',label = 'No')
g.edge('Check Refrigerator for food','Cook',label = 'Yes')
g.edge('Check Refrigerator for food','Check if money available?', label ='No')
g.edge('Check if money available?','Order Food', label = 'Yes')
g.edge('Check if money available?','Dont Order', label ='No')
g

# %% [markdown]
# The degree of a vertex is given by the number of edges incident or leaving from it.
# degree of Am I hungry?: "2"
# degree of Check Refrigerator for food: "3"
# degree of Go to Sleep: "1"
# degree of Cook: "1"
# degree of Check if money avaialable?: "3"
# degree of Order Food: "1"
# degree of Dont Order: "1"

# %% [markdown]
# # Cycle in Structure
# Since the tree is connected, it has no cycle. The edges of a tree with 'n' vertices are 'n-1'. If it contains one more edge than 'n-1,' the extra edge must clearly match up with two vertices, resulting in the formation of a cycle.
